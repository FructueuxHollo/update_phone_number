# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("contacts.csv")
pd.set_option("display.max_columns", None)
data.head()
# Out:
#                  First Name Middle Name Last Name  Phonetic First Name  \
# 0                         ~      Lucien     MEHOU                  NaN
# 1             ~dahkenangnon         NaN       NaN                  NaN
# 2                       Abd         Doc   Magalay                  NaN
# 3                     Abdul      Koyoum    EHISSE                  NaN
# 4  Abomey Albert Akpagladja       Major   Central                  NaN
#
#    Phonetic Middle Name  Phonetic Last Name Name Prefix  Name Suffix  \
# 0                   NaN                 NaN         NaN          NaN
# 1                   NaN                 NaN         NaN          NaN
# 2                   NaN                 NaN         NaN          NaN
# 3                   NaN                 NaN         NaN          NaN
# 4                   NaN                 NaN         NaN          NaN
#
#    Nickname  File As Organization Name  Organization Title  \
# 0       NaN      NaN    ~ Lucien MEHOU                 NaN
# ...

# %%
data.shape
# Out:
# (540, 34)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540 entries, 0 to 539
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   First Name                    497 non-null    object
#  1   Middle Name                   65 non-null     object
#  2   Last Name                     292 non-null    object
#  3   Phonetic First Name           0 non-null      float64
#  4   Phonetic Middle Name          0 non-null      float64
#  5   Phonetic Last Name            0 non-null      float64
#  6   Name Prefix                   16 non-null     object
#  7   Name Suffix                   0 non-null      float64
#  8   Nickname                      0 non-null      float64
#  9   File As                       0 non-null      float64
#  10  Organization Name             25 non-null     object
#  11  Organization Title            0 non-null      float64
# ...

# %%
phone_numbers = data[["Phone 1 - Value","Phone 2 - Value","Phone 3 - Value"]]
phone_numbers.sample(10)
# Out:
#                Phone 1 - Value  Phone 2 - Value  Phone 3 - Value
# 191  66153202 ::: +22966153202              NaN              NaN
# 400               +22964453497              NaN              NaN
# 270               +22964337424              NaN              NaN
# 188                        NaN              NaN              NaN
# 37                +22960613472              NaN              NaN
# 281               +22960385969              NaN              NaN
# 404               +22997716737              NaN              NaN
# 146               +22997778519     2.295570e+10              NaN
# 427               +22969907573              NaN              NaN
# 483  61917133 ::: +22961917133              NaN              NaN

# %%
phone_numbers.iloc(191)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 191
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14256\1242301029.py in ?()
# ----> 1 phone_numbers.iloc(191)
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     734         # we need to return a copy of ourselves
#     735         new_self = type(self)(self.name, self.obj)
#     736
#     737         if axis is not None:
# ...
